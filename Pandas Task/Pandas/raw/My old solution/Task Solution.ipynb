# %% [markdown]
# # Ingest all files:

# %%
import pandas as pd
import datetime

# %%
circ=pd.read_csv('circuits.csv')

# %%
circ
# Out:
#     circuitId   circuitRef                                  name  \
# 0           1  albert_park        Albert Park Grand Prix Circuit
# 1           2       sepang          Sepang International Circuit
# 2           3      bahrain         Bahrain International Circuit
# 3           4    catalunya        Circuit de Barcelona-Catalunya
# 4           5     istanbul                         Istanbul Park
# ..        ...          ...                                   ...
# 72         73          BAK                     Baku City Circuit
# 73         74        hanoi                  Hanoi Street Circuit
# 74         75     portimao    Autódromo Internacional do Algarve
# 75         76      mugello  Autodromo Internazionale del Mugello
# 76         77       jeddah                 Jeddah Street Circuit
#
#         location       country       lat        lng  alt  \
# 0      Melbourne     Australia -37.84970  144.96800   10
# 1   Kuala Lumpur      Malaysia   2.76083  101.73800   18
# ...

# %%
circ.drop('url',axis=1,inplace=True)

# %%
circ.rename(columns={'circuitId':'circuit_Id','circuitRef':'circuit_Ref'},inplace=True)

# %%
circ['time_stamp']=datetime.datetime.now()

# %%
circ
# Out:
#     circuit_Id  circuit_Ref                                  name  \
# 0            1  albert_park        Albert Park Grand Prix Circuit
# 1            2       sepang          Sepang International Circuit
# 2            3      bahrain         Bahrain International Circuit
# 3            4    catalunya        Circuit de Barcelona-Catalunya
# 4            5     istanbul                         Istanbul Park
# ..         ...          ...                                   ...
# 72          73          BAK                     Baku City Circuit
# 73          74        hanoi                  Hanoi Street Circuit
# 74          75     portimao    Autódromo Internacional do Algarve
# 75          76      mugello  Autodromo Internazionale del Mugello
# 76          77       jeddah                 Jeddah Street Circuit
#
#         location       country       lat        lng  alt  \
# 0      Melbourne     Australia -37.84970  144.96800   10
# ...

# %%
circ.to_csv('My_circuit',index=False)

# %%
pd.read_csv('My_circuit')
# Out:
#     circuit_Id  circuit_Ref                                  name  \
# 0            1  albert_park        Albert Park Grand Prix Circuit
# 1            2       sepang          Sepang International Circuit
# 2            3      bahrain         Bahrain International Circuit
# 3            4    catalunya        Circuit de Barcelona-Catalunya
# 4            5     istanbul                         Istanbul Park
# ..         ...          ...                                   ...
# 72          73          BAK                     Baku City Circuit
# 73          74        hanoi                  Hanoi Street Circuit
# 74          75     portimao    Autódromo Internacional do Algarve
# 75          76      mugello  Autodromo Internazionale del Mugello
# 76          77       jeddah                 Jeddah Street Circuit
#
#         location       country       lat        lng  alt  \
# 0      Melbourne     Australia -37.84970  144.96800   10
# ...

# %% [markdown]
# # 2nd file

# %%
const=pd.read_json('constructors.json',lines=True)

# %%
const
# Out:
#      constructorId constructorRef            name nationality  \
# 0                1        mclaren         McLaren     British
# 1                2     bmw_sauber      BMW Sauber      German
# 2                3       williams        Williams     British
# 3                4        renault         Renault      French
# 4                5     toro_rosso      Toro Rosso     Italian
# ..             ...            ...             ...         ...
# 206            209          manor  Manor Marussia     British
# 207            210           haas    Haas F1 Team    American
# 208            211   racing_point    Racing Point     British
# 209            213     alphatauri      AlphaTauri     Italian
# 210            214         alpine  Alpine F1 Team      French
#
#                                                    url
# 0                 http://en.wikipedia.org/wiki/McLaren
# 1              http://en.wikipedia.org/wiki/BMW_Sauber
# ...

# %%
const.drop('url',axis=1,inplace=True)

# %%
const.rename(columns={'constructorId':'constructor_Id','constructorRef':'constructor_Ref'},inplace=True)

# %%
const['time_stamp']=datetime.datetime.now()

# %%
const
# Out:
#      constructor_Id constructor_Ref            name nationality  \
# 0                 1         mclaren         McLaren     British
# 1                 2      bmw_sauber      BMW Sauber      German
# 2                 3        williams        Williams     British
# 3                 4         renault         Renault      French
# 4                 5      toro_rosso      Toro Rosso     Italian
# ..              ...             ...             ...         ...
# 206             209           manor  Manor Marussia     British
# 207             210            haas    Haas F1 Team    American
# 208             211    racing_point    Racing Point     British
# 209             213      alphatauri      AlphaTauri     Italian
# 210             214          alpine  Alpine F1 Team      French
#
#                     time_stamp
# 0   2025-03-25 20:25:18.656375
# 1   2025-03-25 20:25:18.656375
# 2   2025-03-25 20:25:18.656375
# 3   2025-03-25 20:25:18.656375
# 4   2025-03-25 20:25:18.656375
# ...

# %%
const.to_csv('My_constructor',index=False)

# %%
pd.read_csv('My_constructor')
# Out:
#      constructor_Id constructor_Ref            name nationality  \
# 0                 1         mclaren         McLaren     British
# 1                 2      bmw_sauber      BMW Sauber      German
# 2                 3        williams        Williams     British
# 3                 4         renault         Renault      French
# 4                 5      toro_rosso      Toro Rosso     Italian
# ..              ...             ...             ...         ...
# 206             209           manor  Manor Marussia     British
# 207             210            haas    Haas F1 Team    American
# 208             211    racing_point    Racing Point     British
# 209             213      alphatauri      AlphaTauri     Italian
# 210             214          alpine  Alpine F1 Team      French
#
#                      time_stamp
# 0    2025-03-25 20:25:18.656375
# 1    2025-03-25 20:25:18.656375
# 2    2025-03-25 20:25:18.656375
# 3    2025-03-25 20:25:18.656375
# ...

# %% [markdown]
# # 3rd

# %%
dri=pd.read_json('drivers.json',lines=True)

# %%
dri
# Out:
#      driverId          driverRef number code  \
# 0           1           hamilton     44  HAM
# 1           2           heidfeld     \N  HEI
# 2           3            rosberg      6  ROS
# 3           4             alonso     14  ALO
# 4           5         kovalainen     \N  KOV
# ..        ...                ...    ...  ...
# 848       850  pietro_fittipaldi     51  FIT
# 849       851             aitken     89  AIT
# 850       852            tsunoda     \N  TSU
# 851       853            mazepin     \N  MAZ
# 852       854    mick_schumacher     \N  SCH
#
#                                                 name         dob nationality  \
# 0       {'forename': 'Lewis', 'surname': 'Hamilton'}  1985-01-07     British
# 1        {'forename': 'Nick', 'surname': 'Heidfeld'}  1977-05-10      German
# 2         {'forename': 'Nico', 'surname': 'Rosberg'}  1985-06-27      German
# 3      {'forename': 'Fernando', 'surname': 'Alonso'}  1981-07-29     Spanish
# ...

# %%
dri.drop('url',axis=1,inplace=True)

# %%
dri.rename(columns={'driverId':'driver_Id','driverRef':'driver_Ref'},inplace=True)

# %%
dri['time_stamp']=datetime.datetime.now()

# %%
dri
# Out:
#      driver_Id         driver_Ref number code  \
# 0            1           hamilton     44  HAM
# 1            2           heidfeld     \N  HEI
# 2            3            rosberg      6  ROS
# 3            4             alonso     14  ALO
# 4            5         kovalainen     \N  KOV
# ..         ...                ...    ...  ...
# 848        850  pietro_fittipaldi     51  FIT
# 849        851             aitken     89  AIT
# 850        852            tsunoda     \N  TSU
# 851        853            mazepin     \N  MAZ
# 852        854    mick_schumacher     \N  SCH
#
#                                                 name         dob nationality  \
# 0       {'forename': 'Lewis', 'surname': 'Hamilton'}  1985-01-07     British
# 1        {'forename': 'Nick', 'surname': 'Heidfeld'}  1977-05-10      German
# 2         {'forename': 'Nico', 'surname': 'Rosberg'}  1985-06-27      German
# 3      {'forename': 'Fernando', 'surname': 'Alonso'}  1981-07-29     Spanish
# ...

# %%
dri.to_csv('My_driver',index=False)

# %%
pd.read_csv('My_driver')
# Out:
#      driver_Id         driver_Ref number code  \
# 0            1           hamilton     44  HAM
# 1            2           heidfeld     \N  HEI
# 2            3            rosberg      6  ROS
# 3            4             alonso     14  ALO
# 4            5         kovalainen     \N  KOV
# ..         ...                ...    ...  ...
# 848        850  pietro_fittipaldi     51  FIT
# 849        851             aitken     89  AIT
# 850        852            tsunoda     \N  TSU
# 851        853            mazepin     \N  MAZ
# 852        854    mick_schumacher     \N  SCH
#
#                                                 name         dob nationality  \
# 0       {'forename': 'Lewis', 'surname': 'Hamilton'}  1985-01-07     British
# 1        {'forename': 'Nick', 'surname': 'Heidfeld'}  1977-05-10      German
# 2         {'forename': 'Nico', 'surname': 'Rosberg'}  1985-06-27      German
# 3      {'forename': 'Fernando', 'surname': 'Alonso'}  1981-07-29     Spanish
# ...

# %% [markdown]
# # 4th

# %%
pit=pd.read_json('pit_stops.json')

# %%
pit
# Out:
#       raceId  driverId  stop  lap      time duration  milliseconds
# 0        841       153     1    1  17:05:23   26.898         26898
# 1        841        30     1    1  17:05:52   25.021         25021
# 2        841        17     1   11  17:20:48   23.426         23426
# 3        841         4     1   12  17:22:34   23.251         23251
# 4        841        13     1   13  17:24:10   23.842         23842
# ...      ...       ...   ...  ...       ...      ...           ...
# 8025    1047        20     1   35  18:17:15    22.04         22040
# 8026    1047       849     2   35  18:17:41   22.384         22384
# 8027    1047       817     1   39  18:23:37   22.123         22123
# 8028    1047       825     2   47  18:39:11   23.098         23098
# 8029    1047       850     3   48  18:41:11   23.217         23217
#
# [8030 rows x 7 columns]

# %%
pit.rename(columns={'raceId':'race_Id','driverId':'driver_Id','milliseconds':'milli_seconds'},inplace=True)

# %%
pit['time_stamp']=datetime.datetime.now()

# %%
pit
# Out:
#       race_Id  driver_Id  stop  lap      time duration  milli_seconds  \
# 0         841        153     1    1  17:05:23   26.898          26898
# 1         841         30     1    1  17:05:52   25.021          25021
# 2         841         17     1   11  17:20:48   23.426          23426
# 3         841          4     1   12  17:22:34   23.251          23251
# 4         841         13     1   13  17:24:10   23.842          23842
# ...       ...        ...   ...  ...       ...      ...            ...
# 8025     1047         20     1   35  18:17:15    22.04          22040
# 8026     1047        849     2   35  18:17:41   22.384          22384
# 8027     1047        817     1   39  18:23:37   22.123          22123
# 8028     1047        825     2   47  18:39:11   23.098          23098
# 8029     1047        850     3   48  18:41:11   23.217          23217
#
#                      time_stamp
# 0    2025-03-25 20:25:36.647060
# 1    2025-03-25 20:25:36.647060
# ...

# %%
pit.to_csv('My_pit',index=False)

# %%
pd.read_csv('My_pit')
# Out:
#       race_Id  driver_Id  stop  lap      time duration  milli_seconds  \
# 0         841        153     1    1  17:05:23   26.898          26898
# 1         841         30     1    1  17:05:52   25.021          25021
# 2         841         17     1   11  17:20:48   23.426          23426
# 3         841          4     1   12  17:22:34   23.251          23251
# 4         841         13     1   13  17:24:10   23.842          23842
# ...       ...        ...   ...  ...       ...      ...            ...
# 8025     1047         20     1   35  18:17:15    22.04          22040
# 8026     1047        849     2   35  18:17:41   22.384          22384
# 8027     1047        817     1   39  18:23:37   22.123          22123
# 8028     1047        825     2   47  18:39:11   23.098          23098
# 8029     1047        850     3   48  18:41:11   23.217          23217
#
#                       time_stamp
# 0     2025-03-25 20:25:36.647060
# 1     2025-03-25 20:25:36.647060
# ...

# %% [markdown]
# # 5th

# %%
rac=pd.read_csv('races.csv')

# %%
rac
# Out:
#       raceId  year  round  circuitId                      name        date  \
# 0          1  2009      1          1     Australian Grand Prix  2009-03-29
# 1          2  2009      2          2      Malaysian Grand Prix  2009-04-05
# 2          3  2009      3         17        Chinese Grand Prix  2009-04-19
# 3          4  2009      4          3        Bahrain Grand Prix  2009-04-26
# 4          5  2009      5          4        Spanish Grand Prix  2009-05-10
# ...      ...   ...    ...        ...                       ...         ...
# 1053    1069  2021     18         69  United States Grand Prix  2021-10-24
# 1054    1070  2021     19         32    Mexico City Grand Prix  2021-10-31
# 1055    1071  2021     20         18      Brazilian Grand Prix  2021-11-07
# 1056    1072  2021     22         77  Saudi Arabian Grand Prix  2021-12-05
# 1057    1073  2021     23         24      Abu Dhabi Grand Prix  2021-12-12
#
#           time                                                url
# ...

# %%
rac.drop('url',axis=1,inplace=True)

# %%
rac.rename(columns={'raceId':'race_Id','circuitId':'circuit_Id'},inplace=True)

# %%
rac['time_stamp']=datetime.datetime.now()

# %%
rac
# Out:
#       race_Id  year  round  circuit_Id                      name        date  \
# 0           1  2009      1           1     Australian Grand Prix  2009-03-29
# 1           2  2009      2           2      Malaysian Grand Prix  2009-04-05
# 2           3  2009      3          17        Chinese Grand Prix  2009-04-19
# 3           4  2009      4           3        Bahrain Grand Prix  2009-04-26
# 4           5  2009      5           4        Spanish Grand Prix  2009-05-10
# ...       ...   ...    ...         ...                       ...         ...
# 1053     1069  2021     18          69  United States Grand Prix  2021-10-24
# 1054     1070  2021     19          32    Mexico City Grand Prix  2021-10-31
# 1055     1071  2021     20          18      Brazilian Grand Prix  2021-11-07
# 1056     1072  2021     22          77  Saudi Arabian Grand Prix  2021-12-05
# 1057     1073  2021     23          24      Abu Dhabi Grand Prix  2021-12-12
#
#           time                 time_stamp
# ...

# %%
rac.rename(columns={'name':'race_name'},inplace=True)
rac.to_csv('my_races',index=False)

# %%
pd.read_csv('my_races')
# Out:
#       race_Id  year  round  circuit_Id                 race_name        date  \
# 0           1  2009      1           1     Australian Grand Prix  2009-03-29
# 1           2  2009      2           2      Malaysian Grand Prix  2009-04-05
# 2           3  2009      3          17        Chinese Grand Prix  2009-04-19
# 3           4  2009      4           3        Bahrain Grand Prix  2009-04-26
# 4           5  2009      5           4        Spanish Grand Prix  2009-05-10
# ...       ...   ...    ...         ...                       ...         ...
# 1053     1069  2021     18          69  United States Grand Prix  2021-10-24
# 1054     1070  2021     19          32    Mexico City Grand Prix  2021-10-31
# 1055     1071  2021     20          18      Brazilian Grand Prix  2021-11-07
# 1056     1072  2021     22          77  Saudi Arabian Grand Prix  2021-12-05
# 1057     1073  2021     23          24      Abu Dhabi Grand Prix  2021-12-12
#
#           time                  time_stamp
# ...

# %% [markdown]
# # 6th

# %%
resu=pd.read_json('results.json',lines=True)

# %%
resu
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 24955     24961    1047       841             51     99    14       16
# 24956     24962    1047       849              3      6    18       17
# 24957     24963    1047       825            210     20    20       18
# 24958     24964    1047       850            210     51    17       19
# 24959     24965    1047       815            211     11    19       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# ...

# %%
resu.rename(columns={'resultId':'result_Id','raceId':'race_Id','constructorId':'constructor_Id','positionOrder':'position_Order','milliseconds':'milli_seconds',
                     'fastestLap':'fastest_Lap','fastestLapTime':'fastest_Lap_time',
                     'fastestLapSpeed':'fastest_Lap_Speed','positionText':'position_Text','driverId':'driver_Id'},inplace=True)

# %%
resu['time_stamp']=datetime.datetime.now()

# %%
resu
# Out:
#        result_Id  race_Id  driver_Id  constructor_Id number  grid position  \
# 0              1       18          1               1     22     1        1
# 1              2       18          2               2      3     5        2
# 2              3       18          3               3      7     7        3
# 3              4       18          4               4      5    11        4
# 4              5       18          5               1     23     3        5
# ...          ...      ...        ...             ...    ...   ...      ...
# 24955      24961     1047        841              51     99    14       16
# 24956      24962     1047        849               3      6    18       17
# 24957      24963     1047        825             210     20    20       18
# 24958      24964     1047        850             210     51    17       19
# 24959      24965     1047        815             211     11    19       \N
#
# ...

# %%
resu.to_csv('my_result',index=False)

# %%
pd.read_csv('my_result')
# Out:
#        result_Id  race_Id  driver_Id  constructor_Id number  grid position  \
# 0              1       18          1               1     22     1        1
# 1              2       18          2               2      3     5        2
# 2              3       18          3               3      7     7        3
# 3              4       18          4               4      5    11        4
# 4              5       18          5               1     23     3        5
# ...          ...      ...        ...             ...    ...   ...      ...
# 24955      24961     1047        841              51     99    14       16
# 24956      24962     1047        849               3      6    18       17
# 24957      24963     1047        825             210     20    20       18
# 24958      24964     1047        850             210     51    17       19
# 24959      24965     1047        815             211     11    19       \N
#
# ...

# %% [markdown]
# # Transformed:
# ## ............................Race result:

# %%
circuit=pd.read_csv('My_circuit')

# %%
circuit.head(2)
# Out:
#    circuit_Id  circuit_Ref                            name      location  \
# 0           1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1           2       sepang    Sepang International Circuit  Kuala Lumpur
#
#      country       lat      lng  alt                  time_stamp
# 0  Australia -37.84970  144.968   10  2025-03-25 20:24:46.794786
# 1   Malaysia   2.76083  101.738   18  2025-03-25 20:24:46.794786

# %%
races=pd.read_csv('my_races')

# %%
races.head(2)
# Out:
#    race_Id  year  round  circuit_Id              race_name        date  \
# 0        1  2009      1           1  Australian Grand Prix  2009-03-29
# 1        2  2009      2           2   Malaysian Grand Prix  2009-04-05
#
#        time                  time_stamp
# 0  06:00:00  2025-03-25 20:25:42.867636
# 1  09:00:00  2025-03-25 20:25:42.867636

# %%
driver=pd.read_csv('My_driver')

# %%
driver.head(2)
# Out:
#    driver_Id driver_Ref number code  \
# 0          1   hamilton     44  HAM
# 1          2   heidfeld     \N  HEI
#
#                                            name         dob nationality  \
# 0  {'forename': 'Lewis', 'surname': 'Hamilton'}  1985-01-07     British
# 1   {'forename': 'Nick', 'surname': 'Heidfeld'}  1977-05-10      German
#
#                    time_stamp
# 0  2025-03-25 20:25:29.051843
# 1  2025-03-25 20:25:29.051843

# %%
result=pd.read_csv('my_result')

# %%
result.head(2)
# Out:
#    result_Id  race_Id  driver_Id  constructor_Id number  grid position  \
# 0          1       18          1               1     22     1        1
# 1          2       18          2               2      3     5        2
#
#   position_Text  position_Order  points  laps         time milli_seconds  \
# 0             1               1    10.0    58  1:34:50.616       5690616
# 1             2               2     8.0    58       +5.478       5696094
#
#   fastest_Lap rank fastest_Lap_time fastest_Lap_Speed  statusId  \
# 0          39    2         1:27.452             218.3         1
# 1          41    3         1:27.739           217.586         1
#
#                    time_stamp
# 0  2025-03-25 20:33:53.075682
# 1  2025-03-25 20:33:53.075682

# %%
constructor=pd.read_csv('My_constructor')

# %%
constructor.head(2)
# Out:
#    constructor_Id constructor_Ref        name nationality  \
# 0               1         mclaren     McLaren     British
# 1               2      bmw_sauber  BMW Sauber      German
#
#                    time_stamp
# 0  2025-03-25 20:25:18.656375
# 1  2025-03-25 20:25:18.656375

# %%
race_name=races['race_name']

# %%
race_name.head(2)
# Out:
# 0    Australian Grand Prix
# 1     Malaysian Grand Prix
# Name: race_name, dtype: object

# %%
race_year=races['year']

# %%
race_year.head(2)
# Out:
# 0    2009
# 1    2009
# Name: year, dtype: int64

# %%
# circuits_location=

# %%
race_date=races['date']

# %%
race_date.head(2)
# Out:
# 0    2009-03-29
# 1    2009-04-05
# Name: date, dtype: object

# %%
driver_name=driver['name']

# %%
driver_name
# Out:
# 0         {'forename': 'Lewis', 'surname': 'Hamilton'}
# 1          {'forename': 'Nick', 'surname': 'Heidfeld'}
# 2           {'forename': 'Nico', 'surname': 'Rosberg'}
# 3        {'forename': 'Fernando', 'surname': 'Alonso'}
# 4      {'forename': 'Heikki', 'surname': 'Kovalainen'}
#                             ...
# 848    {'forename': 'Pietro', 'surname': 'Fittipaldi'}
# 849          {'forename': 'Jack', 'surname': 'Aitken'}
# 850         {'forename': 'Yuki', 'surname': 'Tsunoda'}
# 851       {'forename': 'Nikita', 'surname': 'Mazepin'}
# 852      {'forename': 'Mick', 'surname': 'Schumacher'}
# Name: name, Length: 853, dtype: object

# %%
driver[driver_name=='forename']['name']
# Out:
# Series([], Name: name, dtype: object)

# %%
driver_number=driver['number']

# %%
driver_number.head(2)
# Out:
# 0    44
# 1    \N
# Name: number, dtype: object

# %%
driver_nationality=driver['nationality']

# %%
driver_nationality.head(2)
# Out:
# 0    British
# 1     German
# Name: nationality, dtype: object

# %%
driver_position = result['position']

# %%
driver_position.head(2)
# Out:
# 0    1
# 1    2
# Name: position, dtype: object

# %%
circuits_location=circuit['location']

# %%
circuits_location.head(2)
# Out:
# 0       Melbourne
# 1    Kuala Lumpur
# Name: location, dtype: object

# %%
fastest_lap=result['laps']

# %%
fastest_lap.head(2)
# Out:
# 0    58
# 1    58
# Name: laps, dtype: int64

# %%
race_time=races['time']

# %%
race_time.head(2)
# Out:
# 0    06:00:00
# 1    09:00:00
# Name: time, dtype: object

# %%
points=result['points']

# %%
points.head(2)
# Out:
# 0    10.0
# 1     8.0
# Name: points, dtype: float64

# %%
team=pd.DataFrame([race_name, race_year, circuits_location,race_date, driver_name, driver_number,driver_nationality
	, driver_position, fastest_lap, race_time,points])

# %%
team
# Out:
#                                                     0      \
# race_name                           Australian Grand Prix
# year                                                 2009
# location                                        Melbourne
# date                                           2009-03-29
# name         {'forename': 'Lewis', 'surname': 'Hamilton'}
# number                                                 44
# nationality                                       British
# position                                                1
# laps                                                   58
# time                                             06:00:00
# points                                                 10
#
#                                                    1      \
# race_name                           Malaysian Grand Prix
# year                                                2009
# location                                    Kuala Lumpur
# ...

# %%
final_team=team.transpose()

# %%
final_team
# Out:
#                    race_name  year      location        date  \
# 0      Australian Grand Prix  2009     Melbourne  2009-03-29
# 1       Malaysian Grand Prix  2009  Kuala Lumpur  2009-04-05
# 2         Chinese Grand Prix  2009        Sakhir  2009-04-19
# 3         Bahrain Grand Prix  2009      Montmeló  2009-04-26
# 4         Spanish Grand Prix  2009      Istanbul  2009-05-10
# ...                      ...   ...           ...         ...
# 24955                    NaN   NaN           NaN         NaN
# 24956                    NaN   NaN           NaN         NaN
# 24957                    NaN   NaN           NaN         NaN
# 24958                    NaN   NaN           NaN         NaN
# 24959                    NaN   NaN           NaN         NaN
#
#                                                   name number nationality  \
# 0         {'forename': 'Lewis', 'surname': 'Hamilton'}     44     British
# 1          {'forename': 'Nick', 'surname': 'Heidfeld'}     \N      German
# ...

# %%
final_team['name']
# Out:
# 0           {'forename': 'Lewis', 'surname': 'Hamilton'}
# 1            {'forename': 'Nick', 'surname': 'Heidfeld'}
# 2             {'forename': 'Nico', 'surname': 'Rosberg'}
# 3          {'forename': 'Fernando', 'surname': 'Alonso'}
# 4        {'forename': 'Heikki', 'surname': 'Kovalainen'}
#                               ...
# 24955                                                NaN
# 24956                                                NaN
# 24957                                                NaN
# 24958                                                NaN
# 24959                                                NaN
# Name: name, Length: 24960, dtype: object

# %% [markdown]
# # Drivers standing:

# %%
result=pd.read_csv('my_result')

# %%
result
# Out:
#        result_Id  race_Id  driver_Id  constructor_Id number  grid position  \
# 0              1       18          1               1     22     1        1
# 1              2       18          2               2      3     5        2
# 2              3       18          3               3      7     7        3
# 3              4       18          4               4      5    11        4
# 4              5       18          5               1     23     3        5
# ...          ...      ...        ...             ...    ...   ...      ...
# 24955      24961     1047        841              51     99    14       16
# 24956      24962     1047        849               3      6    18       17
# 24957      24963     1047        825             210     20    20       18
# 24958      24964     1047        850             210     51    17       19
# 24959      24965     1047        815             211     11    19       \N
#
# ...

# %%
gp=final_team.groupby('name')

# %%
gp

# %%
gp['year']

# %%
gp['points']

# %%
# gp.describe(include=[categorical] )

# %%
drivers_standing=pd.DataFrame([race_year,driver_name,driver_nationality,points]).transpose()

# %%
drivers_standing
# Out:
#        year                                             name nationality  \
# 0      2009     {'forename': 'Lewis', 'surname': 'Hamilton'}     British
# 1      2009      {'forename': 'Nick', 'surname': 'Heidfeld'}      German
# 2      2009       {'forename': 'Nico', 'surname': 'Rosberg'}      German
# 3      2009    {'forename': 'Fernando', 'surname': 'Alonso'}     Spanish
# 4      2009  {'forename': 'Heikki', 'surname': 'Kovalainen'}     Finnish
# ...     ...                                              ...         ...
# 24955   NaN                                              NaN         NaN
# 24956   NaN                                              NaN         NaN
# 24957   NaN                                              NaN         NaN
# 24958   NaN                                              NaN         NaN
# 24959   NaN                                              NaN         NaN
#
#       points
# 0         10
# 1          8
# 2          6
# 3          5
# 4          4
# ...
