# %%
import matplotlib.pyplot as plt

# %%
x=[5,7,8,7,2,17,2,9,4,11,12,9,6]
y=[99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
x=[5,7,8,7,2,17,2,9,4,11,12,9,6]
y=[99,86,87,88,111,86,103,87,94,78,77,85,86]
slope,intercept,r,p,std_err=stats.linregress(x,y)
def myfunc(x):
    return slope*X+intercept
mymodel =list(map(myfunc,x))
plt.scatter(x,y)
plt.plot(x,mymodel)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 6
#       4 def myfunc(x):
#       5     return slope*X+intercept
# ----> 6 mymodel =list(map(myfunc,x))
#       7 plt.scatter(x,y)
#       8 plt.plot(x,mymodel)
#
# Cell In[14], line 5, in myfunc(x)
#       4 def myfunc(x):
# ----> 5     return slope*X+intercept
#
# NameError: name 'X' is not defined

# %%
import numpy as np
x=np.random.uniform(0.0,5.0,250)
print(x)
# Out:
# [1.38947295 3.59236724 4.95936916 2.974835   3.81448061 3.15945204
#  1.74742648 4.86570858 4.90341241 2.22684042 3.71923529 4.33363841
#  1.68840623 0.48676464 1.45183559 4.74835509 1.0278332  4.27243019
#  0.71181285 2.8944218  3.26640255 1.08858561 1.26793534 1.63937016
#  2.14311462 3.81035167 2.33624833 3.47587579 4.57608446 1.43332122
#  4.48765636 2.56655088 1.37129465 3.0231732  0.76572048 1.84864716
#  1.98388104 0.35344033 3.65851819 3.38238656 1.4840968  3.88732473
#  3.55354384 4.33010157 3.44773619 3.33319919 3.94609373 2.43822083
#  2.40845902 1.74567502 1.59513438 1.4039621  0.6197478  2.46336487
#  2.79873468 4.45536958 2.76386508 4.33558302 1.33114874 2.03325353
#  3.24410864 0.82360951 1.61268944 1.84566902 0.53476597 2.82408344
#  4.25124585 3.64686517 1.433519   3.43542974 2.57136981 1.2944934
#  2.11590015 2.53864177 3.22062619 3.31275811 3.91921477 0.56692794
#  0.52871398 0.02406886 4.48986066 2.36188757 1.27596755 3.95634833
#  3.34149538 4.18113014 1.9481874  1.94676452 2.33741893 4.64806007
#  4.32768194 4.78886856 0.775894   4.26380244 0.6852503  1.69366644
#  3.72451754 3.03126121 4.58309582 4.48394276 0.09882629 3.68835113
#  4.33482332 0.76493666 3.71314666 2.50543658 3.75126007 0.70372424
#  0.33447879 1.34681602 3.99427762 0.3843072  3.3797274  3.01144544
#  1.08296519 3.302138   4.78691359 4.43313844 0.71078011 4.81990813
#  3.13475306 3.82642844 2.64667308 0.90293105 4.38862752 4.72191396
#  1.33564131 4.32345995 2.83698645 1.83786627 1.31140557 4.15787113
#  4.05053488 3.33473253 4.95895785 2.10560533 4.25116974 2.07643403
#  4.23980475 0.58486623 4.29071904 4.63822457 1.41281922 3.179449
#  1.82676627 3.11348029 1.06790233 1.69369198 0.7338531  3.29896257
#  1.92585807 1.090389   3.55152356 0.17130137 2.63038463 3.50163603
#  3.54286231 3.06325018 0.7800957  0.10405761 3.3332285  4.9316039
#  1.33070886 2.00578064 4.96727927 3.30719817 2.39504172 2.30368066
#  0.23329025 0.12385453 3.3537748  3.94584865 1.31021915 2.54865088
#  1.65350764 2.82191792 0.18285728 2.67151749 0.38264121 2.34949503
#  4.27630094 0.73409935 2.80237666 3.82813929 4.9903629  0.25755586
#  1.28771361 1.64298245 4.18896087 2.02137631 0.24956446 4.38722162
#  4.29160586 2.1900261  2.42600734 4.24973171 0.52119836 3.43113332
#  1.13439765 2.24276466 2.99643887 3.40806603 1.533432   0.45021497
#  2.81425272 1.66075495 4.1626204  2.38917071 3.87822172 3.74197685
#  3.38516557 3.24318589 1.17072552 4.58007112 0.60063908 1.38007046
#  1.36168833 4.02806804 0.18350722 2.69487539 2.79446332 3.91015301
#  2.09914137 2.13992017 3.60156982 0.51747122 1.53843989 2.68780924
#  2.61156322 2.59095385 0.95655406 4.70527956 4.02066538 1.80703205
#  3.31072952 1.47529759 0.55859506 2.23336729 0.36185788 0.1528789
#  2.97313382 2.02579435 4.36222887 4.85120585 1.66165977 1.52854138
#  2.783192   4.64260802 3.99652456 3.52806991]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=np.random.uniform(0.0,5.0,250)
y=pd.DataFrame(x)
print(y)
plt.hist(x,5)
plt.show()
# Out:
#             0
# 0    2.045172
# 1    0.071693
# 2    2.046735
# 3    3.111816
# 4    2.793131
# ..        ...
# 245  0.418858
# 246  3.228414
# 247  4.917550
# 248  3.107021
# 249  1.478948
#
# [250 rows x 1 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.random.uniform(0.0,5.0,100000)
plt.hist(x,100)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.random.uniform(0.0,5.0,100000)
y=pd.DataFrame(x)
print(y.to_string)
plt.hist(x,100)
plt.show()
# Out:
# <bound method DataFrame.to_string of               0
# 0      4.402881
# 1      2.136363
# 2      2.164230
# 3      1.268893
# 4      3.316658
# ...         ...
# 99995  2.450144
# 99996  4.554711
# 99997  1.410242
# 99998  4.787101
# 99999  4.649703
#
# [100000 rows x 1 columns]>
