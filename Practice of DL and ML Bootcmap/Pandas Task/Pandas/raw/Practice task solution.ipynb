# %%
import pandas as pd

# %%
cir=pd.read_csv('circuits.csv')

# %%
cir.head(2)
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
#
#      country       lat      lng  alt  \
# 0  Australia -37.84970  144.968   10
# 1   Malaysia   2.76083  101.738   18
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...

# %%
cir.drop('url',axis=1,inplace=True)

# %%
cir.rename(columns={'circuitId':'circuit_Id','circuitRef':'circuit_Ref'},inplace=True)

# %%
import datetime

# %%
cir['times_stamp']=datetime.datetime.now()

# %%
cir.head(2)
# Out:
#    circuit_Id  circuit_Ref                            name      location  \
# 0           1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1           2       sepang    Sepang International Circuit  Kuala Lumpur
#
#      country       lat      lng  alt                times_stamp
# 0  Australia -37.84970  144.968   10 2025-03-26 19:47:55.652630
# 1   Malaysia   2.76083  101.738   18 2025-03-26 19:47:55.652630

# %%
cir.to_csv('My_circuit.csv',index=False)

# %%
pd.read_csv('My_circuit.csv').head(2)
# Out:
#    circuit_Id  circuit_Ref                            name      location  \
# 0           1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1           2       sepang    Sepang International Circuit  Kuala Lumpur
#
#      country       lat      lng  alt                 times_stamp
# 0  Australia -37.84970  144.968   10  2025-03-26 19:47:55.652630
# 1   Malaysia   2.76083  101.738   18  2025-03-26 19:47:55.652630

# %% [markdown]
# # 2.

# %%
const=pd.read_json('constructors.json',lines=True)

# %%
const.head(2)
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
#
#                                        url
# 0     http://en.wikipedia.org/wiki/McLaren
# 1  http://en.wikipedia.org/wiki/BMW_Sauber

# %%
const.drop('url',axis=1,inplace=True)

# %%
const.rename(columns={'constructorId':'constructor_Id','constructorRef':'constructor_Ref'},inplace=True)

# %%
const['time_stamp']=datetime.datetime.now()

# %%
const.head(2)
# Out:
#    constructor_Id constructor_Ref        name nationality  \
# 0               1         mclaren     McLaren     British
# 1               2      bmw_sauber  BMW Sauber      German
#
#                   time_stamp
# 0 2025-03-26 19:47:57.776805
# 1 2025-03-26 19:47:57.776805

# %%
const.to_csv('My_constructor.csv',index=False)

# %%
pd.read_csv('My_constructor.csv').head(2)
# Out:
#    constructor_Id constructor_Ref        name nationality  \
# 0               1         mclaren     McLaren     British
# 1               2      bmw_sauber  BMW Sauber      German
#
#                    time_stamp
# 0  2025-03-26 19:47:57.776805
# 1  2025-03-26 19:47:57.776805

# %% [markdown]
# # 3.

# %%
dir=pd.read_json('drivers.json',lines=True)

# %%
dir.head(2)
# Out:
#    driverId driverRef number code  \
# 0         1  hamilton     44  HAM
# 1         2  heidfeld     \N  HEI
#
#                                            name         dob nationality  \
# 0  {'forename': 'Lewis', 'surname': 'Hamilton'}  1985-01-07     British
# 1   {'forename': 'Nick', 'surname': 'Heidfeld'}  1977-05-10      German
#
#                                            url
# 0  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1   http://en.wikipedia.org/wiki/Nick_Heidfeld

# %%
dir.drop('url',axis=1,inplace=True)

# %%
dir['time_stamp']=datetime.datetime.now()

# %%
dir.rename(columns={'driverId':'driver_Id','driverRef':'driver_Ref'},inplace=True)

# %%
dir.head(2)
# Out:
#    driver_Id driver_Ref number code  \
# 0          1   hamilton     44  HAM
# 1          2   heidfeld     \N  HEI
#
#                                            name         dob nationality  \
# 0  {'forename': 'Lewis', 'surname': 'Hamilton'}  1985-01-07     British
# 1   {'forename': 'Nick', 'surname': 'Heidfeld'}  1977-05-10      German
#
#                   time_stamp
# 0 2025-03-26 19:48:03.198639
# 1 2025-03-26 19:48:03.198639

# %%
fname=dir['name'].values

# %%
len(fname)
# Out:
# 853

# %%
# print(fname)

# %%
print(len(fname))
# Out:
# 853

# %%
# print(dir['name'].values[0]['forename'],dir['name'].values[0]['surname'])

# %%
# import numpy as np
# finalname=dir[dir['name'].values==dir['name']['forename'].values]

# %%
finame=[]
finname=[]
for i in range(len(fname)):
    # print(fname[i]['forename'])
    finame.append(fname[i]['forename'])
    finname.append(fname[i]['surname'])
    # fname.append(finalname[i]['surname'])
     # fname.append()
    # dir['name']=f_name
    # print(len(f_name))
# dir['name']=fname
# print(finame)
# print(finname)
# dir['name']=finame+finnmae

# %%
# dir['name']=finame

# %%
rowname=pd.DataFrame(data=[finame,finname],index=['na','sur']).transpose()

# %%
rowname['fine']=rowname['na']+' '+rowname['sur']

# %%
# rowname['fine']

# %%
dir['name']=rowname['fine']

# %%
dir.head(2)
# Out:
#    driver_Id driver_Ref number code            name         dob nationality  \
# 0          1   hamilton     44  HAM  Lewis Hamilton  1985-01-07     British
# 1          2   heidfeld     \N  HEI   Nick Heidfeld  1977-05-10      German
#
#                   time_stamp
# 0 2025-03-26 19:48:03.198639
# 1 2025-03-26 19:48:03.198639

# %%
dir.to_csv('My_driver.csv',index=False)

# %%
# for i in range(len(namef)):
# #     # print(i)
#     print(namef[i]['forename'],namef[i]['surname'])
# # [int(i) for i in range(len(namef))]

# %%
pd.read_csv('My_driver.csv').head(2)
# Out:
#    driver_Id driver_Ref number code            name         dob nationality  \
# 0          1   hamilton     44  HAM  Lewis Hamilton  1985-01-07     British
# 1          2   heidfeld     \N  HEI   Nick Heidfeld  1977-05-10      German
#
#                    time_stamp
# 0  2025-03-26 19:48:03.198639
# 1  2025-03-26 19:48:03.198639

# %% [markdown]
# # 4.

# %%
pit=pd.read_json('pit_stops.json')

# %%
pit.head(2)
# Out:
#    raceId  driverId  stop  lap      time duration  milliseconds
# 0     841       153     1    1  17:05:23   26.898         26898
# 1     841        30     1    1  17:05:52   25.021         25021

# %%
pit.rename(columns={'raceId':'race_Id','driverId':'driver_Id','milliseconds':'milli_seconds'},inplace=True)

# %%
pit['time_stamp']=datetime.datetime.now()

# %%
pit.head(2)
# Out:
#    race_Id  driver_Id  stop  lap      time duration  milli_seconds  \
# 0      841        153     1    1  17:05:23   26.898          26898
# 1      841         30     1    1  17:05:52   25.021          25021
#
#                   time_stamp
# 0 2025-03-26 20:08:57.426485
# 1 2025-03-26 20:08:57.426485

# %%
pit.to_csv("My_pit.csv",index=False)

# %%
pd.read_csv('My_pit.csv').head(2)
# Out:
#    race_Id  driver_Id  stop  lap      time duration  milli_seconds  \
# 0      841        153     1    1  17:05:23   26.898          26898
# 1      841         30     1    1  17:05:52   25.021          25021
#
#                    time_stamp
# 0  2025-03-26 20:08:57.426485
# 1  2025-03-26 20:08:57.426485

# %% [markdown]
# # 5.

# %%
race=pd.read_csv('races.csv')

# %%
race.head(2)
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
#
#        time                                                url
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...

# %%
race.drop('url',axis=1,inplace=True)

# %%
race.rename(columns={'raceId':'race_Id','circuitId':'circuit_Id','name':'race_name'},inplace=True)

# %%
race['timestamp']=datetime.datetime.now()

# %%
race.head(2)
# Out:
#    race_Id  year  round  circuit_Id              race_name        date  \
# 0        1  2009      1           1  Australian Grand Prix  2009-03-29
# 1        2  2009      2           2   Malaysian Grand Prix  2009-04-05
#
#        time                  timestamp
# 0  06:00:00 2025-03-26 20:53:56.531855
# 1  09:00:00 2025-03-26 20:53:56.531855

# %%
race.to_csv('My_race.csv',index=False)

# %%
pd.read_csv('My_race.csv').head(2)
# Out:
#    race_Id  year  round  circuit_Id              race_name        date  \
# 0        1  2009      1           1  Australian Grand Prix  2009-03-29
# 1        2  2009      2           2   Malaysian Grand Prix  2009-04-05
#
#        time                   timestamp
# 0  06:00:00  2025-03-26 20:53:56.531855
# 1  09:00:00  2025-03-26 20:53:56.531855

# %% [markdown]
# # 6.

# %%
res=pd.read_json("results.json",lines=True)

# %%
res.head(2)
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452           218.3         1
# 1         41    3       1:27.739         217.586         1

# %%
res.rename(columns={'resultId':'result_Id','raceId':'race_Id','driverId':'driver_Id',
            'constructorId':'constructor_Id','positionText':'position_Text',
            'positionOrder':'position_Order','milliseconds':'milli_seconds','fastestLap':'fastest_Lap',
            'fastestLapTime':'fastest_Lap_Time','fastestLapSpeed':'fastest_Lap_Speed','statusId':'status_Id'},inplace=True)

# %%
res['time_stamp']=datetime.datetime.now()

# %%
res.head(2)
# Out:
#    result_Id  race_Id  driver_Id  constructor_Id number  grid position  \
# 0          1       18          1               1     22     1        1
# 1          2       18          2               2      3     5        2
#
#   position_Text  position_Order  points  laps         time milli_seconds  \
# 0             1               1    10.0    58  1:34:50.616       5690616
# 1             2               2     8.0    58       +5.478       5696094
#
#   fastest_Lap rank fastest_Lap_Time fastest_Lap_Speed  status_Id  \
# 0          39    2         1:27.452             218.3          1
# 1          41    3         1:27.739           217.586          1
#
#                   time_stamp
# 0 2025-03-26 20:42:27.091055
# 1 2025-03-26 20:42:27.091055

# %%
res.to_csv('My_result.csv',index=False)

# %%
result=pd.read_csv('My_result.csv')

# %%
result.head(2)
# Out:
#    result_Id  race_Id  driver_Id  constructor_Id number  grid position  \
# 0          1       18          1               1     22     1        1
# 1          2       18          2               2      3     5        2
#
#   position_Text  position_Order  points  laps         time milli_seconds  \
# 0             1               1    10.0    58  1:34:50.616       5690616
# 1             2               2     8.0    58       +5.478       5696094
#
#   fastest_Lap rank fastest_Lap_Time fastest_Lap_Speed  status_Id  \
# 0          39    2         1:27.452             218.3          1
# 1          41    3         1:27.739           217.586          1
#
#                    time_stamp
# 0  2025-03-26 20:42:27.091055
# 1  2025-03-26 20:42:27.091055

# %% [markdown]
# # Transformed

# %%
race_name=pd.read_csv('My_race.csv')

# %%
race_name.head(2)
# Out:
#    race_Id  year  round  circuit_Id              race_name        date  \
# 0        1  2009      1           1  Australian Grand Prix  2009-03-29
# 1        2  2009      2           2   Malaysian Grand Prix  2009-04-05
#
#        time                   timestamp
# 0  06:00:00  2025-03-26 20:53:56.531855
# 1  09:00:00  2025-03-26 20:53:56.531855

# %%
race_name=pd.read_csv('My_race.csv')['race_name']

# %%
race_name.head(2)
# Out:
# 0    Australian Grand Prix
# 1     Malaysian Grand Prix
# Name: race_name, dtype: object

# %%
race_year=ra_name['year']

# %%
race_year.head(2)
# Out:
# 0    2009
# 1    2009
# Name: year, dtype: int64

# %%
circuits_location=pd.read_csv('My_circuit.csv')['location']

# %%
circuits_location.head(2)
# Out:
# 0       Melbourne
# 1    Kuala Lumpur
# Name: location, dtype: object

# %%
race_date=ra_name['date']

# %%
race_date.head(2)
# Out:
# 0    2009-03-29
# 1    2009-04-05
# Name: date, dtype: object

# %%
driver_name=pd.read_csv('My_driver.csv')['name']

# %%
driver_name.head(2)
# Out:
# 0    Lewis Hamilton
# 1     Nick Heidfeld
# Name: name, dtype: object

# %%
driver_number=pd.read_csv('My_driver.csv')['number']

# %%
driver_number.head(2)
# Out:
# 0    44
# 1    \N
# Name: number, dtype: object

# %%
driver_nationality=pd.read_csv('My_driver.csv')['nationality']

# %%
driver_nationality.head(2)
# Out:
# 0    British
# 1     German
# Name: nationality, dtype: object

# %%
drivers_position=pd.read_csv('My_result.csv')['position']

# %%
drivers_position.head(2)
# Out:
# 0    1
# 1    2
# Name: position, dtype: object

# %%
fastest_lap=pd.read_csv('My_result.csv')['fastest_Lap']

# %%
fastest_lap.head(2)
# Out:
# 0    39
# 1    41
# Name: fastest_Lap, dtype: object

# %%
race_time=pd.read_csv('My_race.csv')['time']

# %%
race_time.head(2)
# Out:
# 0    06:00:00
# 1    09:00:00
# Name: time, dtype: object

# %%
points=pd.read_csv('My_result.csv')['points']

# %%
points.head(2)
# Out:
# 0    10.0
# 1     8.0
# Name: points, dtype: float64

# %%
team=[race_name,race_year,circuits_location,race_date,driver_name,driver_number,driver_nationality,drivers_position,fastest_lap,race_time,points]

# %%
df=pd.DataFrame(team).transpose()

# %%
df.head(5)
# Out:
#                race_name  year      location        date               name  \
# 0  Australian Grand Prix  2009     Melbourne  2009-03-29     Lewis Hamilton
# 1   Malaysian Grand Prix  2009  Kuala Lumpur  2009-04-05      Nick Heidfeld
# 2     Chinese Grand Prix  2009        Sakhir  2009-04-19       Nico Rosberg
# 3     Bahrain Grand Prix  2009      Montmeló  2009-04-26    Fernando Alonso
# 4     Spanish Grand Prix  2009      Istanbul  2009-05-10  Heikki Kovalainen
#
#   number nationality position fastest_Lap      time points
# 0     44     British        1          39  06:00:00     10
# 1     \N      German        2          41  09:00:00      8
# 2      6      German        3          41  07:00:00      6
# 3     14     Spanish        4          58  12:00:00      5
# 4     \N     Finnish        5          43  12:00:00      4

# %%
df.to_csv('final_result.csv',index=False)

# %%
gpby=df.groupby('points')

# %%
gpby

# %%
gpby.describe()
# Out:
#        race_name                                    year                    \
#            count unique                   top freq count unique   top freq
# points
# 0.00         658     46    Italian Grand Prix   47   658     72  2021   14
# 0.50           0      0                   NaN  NaN     0      0   NaN  NaN
# 1.00          50     25    Italian Grand Prix    6    50     49  2021    2
# 1.33           0      0                   NaN  NaN     0      0   NaN  NaN
# 1.50           0      0                   NaN  NaN     0      0   NaN  NaN
# 2.00          50     25     Monaco Grand Prix    5    50     50  2021    1
# 2.50           0      0                   NaN  NaN     0      0   NaN  NaN
# 3.00          50     22  Brazilian Grand Prix    6    50     50  2021    1
# 3.14           0      0                   NaN  NaN     0      0   NaN  NaN
# 3.50           0      0                   NaN  NaN     0      0   NaN  NaN
# ...
